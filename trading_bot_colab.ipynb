# %%
# !pip install yfinance plotly ipywidgets -q

# %%
# !wget -q https://https://raw.githubusercontent.com/zzpanqing/auto_trading/master/trading_bot_colab.py
exec(open('trading_bot_colab_v8.py').read())
